# %%
# !pip install transformers torch torchvision pillow

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

processor = BlipProcessor.from_pretrained(
    "Salesforce/blip-image-captioning-base"
)

model = BlipForConditionalGeneration.from_pretrained(
    "Salesforce/blip-image-captioning-base"
).to(device)

# %%
# !pip install streamlit

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4dff0d0b-abf7-4df1-b8a5-0620934c04ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4dff0d0b-abf7-4df1-b8a5-0620934c04ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
image = Image.open(list(uploaded.keys())[0]).convert("RGB")

inputs = processor(image, return_tensors="pt").to(device)

out = model.generate(**inputs, max_length=30)

caption = processor.decode(out[0], skip_special_tokens=True)
print("Generated Caption:", caption)

# %%
# %%writefile app.py
import streamlit as st
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image
import torch

st.set_page_config(page_title="AI Image Captioning", layout="centered")
st.title("🖼️ AI Image Caption Generator")

device = "cuda" if torch.cuda.is_available() else "cpu"

@st.cache_resource
def load_model():
    processor = BlipProcessor.from_pretrained(
        "Salesforce/blip-image-captioning-base"
    )
    model = BlipForConditionalGeneration.from_pretrained(
        "Salesforce/blip-image-captioning-base"
    ).to(device)
    return processor, model

processor, model = load_model()

uploaded_file = st.file_uploader("Upload an Image", type=["jpg", "png", "jpeg"])

if uploaded_file:
    image = Image.open(uploaded_file).convert("RGB")
    st.image(image, caption="Uploaded Image", use_column_width=True)

    inputs = processor(image, return_tensors="pt").to(device)
    output = model.generate(**inputs, max_length=30)

    caption = processor.decode(output[0], skip_special_tokens=True)

    st.success("Generated Caption:")
    st.write(caption)

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
ngrok.set_auth_token("3ARNMlU8fPVorO3y5wy7NUoSwk9_7t1pH18dJaEkQxAiqKTd2")

# %%
from pyngrok import ngrok

# Kill previous sessions (important)
# !pkill -f streamlit
# !pkill -f ngrok

# Set the authentication token explicitly in this cell
ngrok.set_auth_token("3ARNMlU8fPVorO3y5wy7NUoSwk9_7t1pH18dJaEkQxAiqKTd2")

# Run streamlit in background
# !streamlit run app.py &>/dev/null&

# Create public link
public_url = ngrok.connect(8501)

# %%
import re

with open('app.py', 'r') as f:
    app_content = f.read()

# Replace st.write with st.markdown for styled output
modified_content = re.sub(
    r"st\.write\(caption\)",
    r"st.markdown(f\"<h2 style='text-align: center; color: #4CAF50;'>{caption}</h2>\", unsafe_allow_html=True)",
    app_content
)

with open('app.py', 'w') as f:
    f.write(modified_content)

print("Modified app.py content:")
print(modified_content)

# %%
import os

file_path = 'app.py'

if os.path.exists(file_path):
    with open(file_path, 'r') as f:
        app_content = f.read()
    print(f"File '{file_path}' found and read successfully. Content length: {len(app_content)} characters.")
    # You can now proceed with modification logic here
    # For example:
    # modified_content = app_content.replace('old_text', 'new_text')
    # with open(file_path, 'w') as f:
    #     f.write(modified_content)
    # print("File modified successfully.")
else:
    print(f"Error: File '{file_path}' does not exist. Please ensure it has been created.")
    # Optionally, create an empty file if that's the desired behavior:
    # with open(file_path, 'w') as f:
    #     f.write('')
    # print(f"Empty file '{file_path}' created.")

# %%
from pyngrok import ngrok

# Kill previous sessions (important)
# !pkill -f streamlit
# !pkill -f ngrok

# Set the authentication token explicitly in this cell
ngrok.set_auth_token("3ARNMlU8fPVorO3y5wy7NUoSwk9_7t1pH18dJaEkQxAiqKTd2")

# Run streamlit in background
# !streamlit run app.py &>/dev/null&

# Create public link
public_url = ngrok.connect(8501)

# %%
import re

with open('app.py', 'r') as f:
    app_content = f.read()

# Replace st.markdown with st.write to undo the change
modified_content = re.sub(
    r"st\.markdown\(f\\\"<h2 style='text-align: center; color: #4CAF50;'>\{caption\}</h2>\\\", unsafe_allow_html=True\)",
    r"st.write(caption)",
    app_content
)

with open('app.py', 'w') as f:
    f.write(modified_content)

print("Reverted app.py content:")
print(modified_content)

# %%
# !pip install pyngrok

from pyngrok import ngrok

# Kill previous sessions (important)
# !pkill -f streamlit
# !pkill -f ngrok

# Set the authentication token explicitly in this cell
ngrok.set_auth_token("3ARNMlU8fPVorO3y5wy7NUoSwk9_7t1pH18dJaEkQxAiqKTd2")

# Run streamlit in background
# !streamlit run app.py &>/dev/null&

# Create public link and display only the public URL
public_url = ngrok.connect(8501)
print(public_url.public_url)
# Out:
# ...
# https://lirellate-annalee-trilaterally.ngrok-free.dev
